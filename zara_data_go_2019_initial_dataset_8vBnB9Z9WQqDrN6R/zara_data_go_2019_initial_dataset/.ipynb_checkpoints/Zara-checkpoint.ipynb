# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ModuleNotFoundError: No module named 'numpy.core._multiarray_umath'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ModuleNotFoundError: No module named 'numpy.core._multiarray_umath'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ModuleNotFoundError: No module named 'numpy.core._multiarray_umath'
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ModuleNotFoundError: No module named 'numpy.core._multiarray_umath'

# %%
pos0 = pd.read_csv("initial_dataset/positions_day_0_day_63.csv")
pos71 = pd.read_csv("initial_dataset/positions_day_71.csv")
prob = pd.read_csv("initial_dataset/product_blocks.csv")
pro = pd.read_csv("initial_dataset/products.csv")
sales = pd.read_csv("initial_dataset/stock_and_sales_day_0_day_63.csv")
stock = pd.read_csv("initial_dataset/stock_day_71_stock_replenishment_days_72-77.csv")

# %%
display(pos0.tail(50))
display(pos71.tail(20))
display(prob.tail(20))
display(pro.tail(20))
display(sales.tail(20))
display(stock.tail(20))
# Out:
#         date_number  product_id  category_id  position
# 969847           63   984808390    989171979       135
# 969848           63   987092895    989171979       132
# 969849           63    64041018    992416396        17
# 969850           63   131317880    992416396         6
# 969851           63   280900660    992416396         8
# 969852           63   295142402    992416396        19
# 969853           63   307910104    992416396        18
# 969854           63   323547175    992416396        15
# 969855           63   338949206    992416396         9
# 969856           63   456689268    992416396         4
# 969857           63   511499041    992416396        16
# 969858           63   545626019    992416396         5
# 969859           63   607423756    992416396        21
# 969860           63   729145751    992416396         3
# 969861           63   847617660    992416396        14
# 969862           63   921678230    992416396        13
# 969863           63   945692323    992416396         2
# 969864           63   979997417    992416396        20
# 969865           63   149315633    996630739        23
# 969866           63   317461669    996630739        13
# 969867           63   333444000    996630739        15
# 969868           63   365881039    996630739        20
# 969869           63   447511737    996630739         3
# 969870           63   463813297    996630739        18
# 969871           63   466978927    996630739         1
# 969872           63   502702756    996630739        14
# 969873           63   520978178    996630739        16
# 969874           63   539084966    996630739         4
# 969875           63   567709953    996630739        22
# 969876           63   578619821    996630739         9
# 969877           63   617090218    996630739         7
# 969878           63   731021496    996630739        12
# 969879           63   769704397    996630739        21
# 969880           63   836239289    996630739        25
# 969881           63   849366004    996630739        17
# 969882           63   903699519    996630739         2
# 969883           63   982701115    996630739        19
# 969884           63    89905356    997362045         9
# 969885           63   118479901    997362045         1
# 969886           63   160513578    997362045         4
# 969887           63   208204343    997362045         2
# 969888           63   217320340    997362045         3
# 969889           63   319518013    997362045        11
# 969890           63   382207567    997362045        12
# 969891           63   418377300    997362045         8
# 969892           63   494340817    997362045         6
# 969893           63   546871331    997362045         5
# 969894           63   648347795    997362045        13
# 969895           63   706861109    997362045        10
# 969896           63   715387790    997362045         7
#        date_number  product_id  category_id  position
# 20009           71   731021496    996630739        15
# 20010           71   769704397    996630739         6
# 20011           71   836239289    996630739        27
# 20012           71   849366004    996630739        20
# 20013           71   895575226    996630739        32
# 20014           71   903699519    996630739         7
# 20015           71   982701115    996630739        22
# 20016           71    89905356    997362045         9
# 20017           71   118479901    997362045         1
# 20018           71   160513578    997362045         4
# 20019           71   208204343    997362045         2
# 20020           71   217320340    997362045         3
# 20021           71   319518013    997362045        11
# 20022           71   382207567    997362045        12
# 20023           71   418377300    997362045         8
# 20024           71   494340817    997362045         6
# 20025           71   546871331    997362045         5
# 20026           71   648347795    997362045        13
# 20027           71   706861109    997362045        10
# 20028           71   715387790    997362045         7
#        product_id  block_id
# 15218   817610912      2773
# 15219   670471069      2773
# 15220    30686283      2773
# 15221   844563765      2773
# 15222    54918949      2773
# 15223   631452361      2773
# 51254                            0                            0
# 51255                            0                            0
# 51256                            0                            0
# 51257                            0                            0
# 51258                            0                            0
# 51259                            1                            0
# 51260                            0                            0
# 51261                            0                            0
# 51262                            0                            0
# 51263                            0                            0
# 51264                            0                            0
# 51265                            0                            0
# 51266                            0                            0
# 51267                            0                            0
#
#        stock_replenishment_days_74  stock_replenishment_days_75  \
# 51248                            1                            0
# 51249                            0                            0
# 51250                            0                            0
# 51251                            0                            0
# 51252                            0                            0
# 51253                            0                            0
# 51254                            0                            0
# 51255                            0                            0
# 51256                            0                            0
# 51257                            0                           -1
# 51258                            0                            0
# 51259                            0                            0
# 51260                            0                            0
# 51261                            0                            0
# 51262                            0                            0
# 51263                            0                            0
# 51264                            0                            0
# 51265                            0                            0
# 51266                            1                            0
# 51267                            0                            0
#
#        stock_replenishment_days_76  stock_replenishment_days_77
# 51248                            0                            1
# 51249                            0                            0
# 51250                            0                            0
# 51251                            1                            0
# 51252                            0                            0
# 51253                            0                            0
# 51254                            0                            0
# 51255                            0                            0
# 51256                            0                            0
# 51257                            1                            0
# 51258                            0                            1
# 51259                            0                            0
# 51260                            0                            0
# 51261                            0                            0
# 51262                            0                            0
# 51263                            0                            0
# 51264                            0                            0
# 51265                            0                            0
# 51266                            0                            0
# 51267                            0                            0

# %% [markdown]
# # Dataframe ventas

# %%
pos0.drop(["category_id"], axis=1, inplace= True)
med = pos0.groupby(["product_id", "date_number"], as_index=False).mean()
med.rename(columns={"position": "mean_position"}, inplace= True)
mini = pos0.groupby(["product_id", "date_number"], as_index=False).min()
mini.rename(columns={"position": "min_position"}, inplace= True)

# %%
df = sales.merge(prob, on=['product_id'])
df = df.merge(pro, on=['product_id'])
df = df.merge(mini, on=['product_id',"date_number"], how="left")
df = df.merge(med, on=['product_id',"date_number"], how="left")

# %%
df.isna().sum()
# Out:
# date_number           0
# product_id            0
# color_id              0
# size_id               0
# sales                 0
# stock                 0
# block_id              0
# family_id             0
# subfamily_id          0
# price                 0
# min_position     186942
# mean_position    186942
# dtype: int64

# %%
df.fillna(0, inplace=True)

# %%
df.drop(["family_id"], inplace=True, axis=1)

# %%
df["weekday"] = df.apply(lambda row: row["date_number"] if row["date_number"] < 7 else row["date_number"] -7 * int(row["date_number"]/7), axis=1)

# %%
df.head()
# Out:
#    date_number  product_id  color_id    size_id  sales  stock  block_id  \
# 0            0      310130  78467031    7026791      1     93      1726
# 1            0      310130  78467031    8015276      2     62      1726
# 2            0      310130  78467031  452052101      1     18      1726
# 3            0      310130  78467031  541898038      2     42      1726
# 4            0      310130  78467031  558685710      3    113      1726
#
#    subfamily_id  price  min_position  mean_position  weekday
# 0     533441312  12.95           3.0      54.333333      0.0
# 1     533441312  12.95           3.0      54.333333      0.0
# 2     533441312  12.95           3.0      54.333333      0.0
# 3     533441312  12.95           3.0      54.333333      0.0
# 4     533441312  12.95           3.0      54.333333      0.0

# %% [markdown]
# # Dataframe previsión

# %%
pos71.drop(["category_id"], axis=1, inplace= True)
med71 = pos71.groupby(["product_id", "date_number"], as_index=False).mean()
med71.rename(columns={"position": "mean_position"}, inplace= True)
mini71 = pos71.groupby(["product_id", "date_number"], as_index=False).min()
mini71.rename(columns={"position": "min_position"}, inplace= True)

# %%
df71 = stock.merge(prob, on=['product_id'])
df71 = df71.merge(pro, on=['product_id'])
df71 = df71.merge(mini71, on=['product_id'], how="left")
df71 = df71.merge(med71, on=['product_id',"date_number"], how="left")

# %%
df71 = df71.rename(columns={"stock_at_day_71": "stock"})

# %%
df7 = df71.copy()

# %%
df71 = df71.drop(["stock_replenishment_days_72",
           "stock_replenishment_days_73",
           "stock_replenishment_days_74",
           "stock_replenishment_days_75",
           "stock_replenishment_days_76",
           "stock_replenishment_days_77"], axis=1)

# %%
df72 = df71.copy()
df72["stock"] = df71["stock"] + df7["stock_replenishment_days_72"]
df72["date_number"] = 72

# %%
df73 = df72.copy()
df73["stock"] = df72["stock"] + df7["stock_replenishment_days_73"]
df73["date_number"] = 73

# %%
df74 = df73.copy()
df74["stock"] = df73["stock"] + df7["stock_replenishment_days_74"]
df74["date_number"] = 74

# %%
df75 = df74.copy()
df75["stock"] = df74["stock"] + df7["stock_replenishment_days_75"]
df75["date_number"] = 75

# %%
df76 = df75.copy()
df76["stock"] = df75["stock"] + df7["stock_replenishment_days_76"]
df76["date_number"] = 76

# %%
df77 = df76.copy()
df77["stock"] = df76["stock"] + df7["stock_replenishment_days_77"]
df77["date_number"] = 77

# %%
df7 = pd.concat([df71, df72, df73, df74, df75, df76, df77])

# %%
df7.sort_values(by=["product_id"], inplace=True)

# %%
df7.reset_index(drop=True, inplace=True)

# %%
df7.drop(["family_id"], inplace=True, axis=1)

# %%
df7["sales"] = 0

# %%
df7.iloc[282]
# Out:
# product_id       7.591500e+05
# color_id         7.352240e+08
# size_id          2.423642e+08
# stock            0.000000e+00
# block_id         1.485000e+03
# subfamily_id     5.379385e+08
# price            1.795000e+01
# date_number               NaN
# min_position              NaN
# mean_position             NaN
# sales            0.000000e+00
# Name: 282, dtype: float64

# %%
df7.isna().sum()
# Out:
# product_id           0
# color_id             0
# size_id              0
# stock                0
# block_id             0
# subfamily_id         0
# price                0
# date_number       5269
# min_position     36883
# mean_position    36883
# sales                0
# dtype: int64

# %%
df7.dropna(subset=["date_number"], inplace=True)

# %%
df7.fillna(0, inplace=True)

# %%
df7["weekday"] = df7.apply(lambda row: row["date_number"] -7 * int(row["date_number"]/7), axis=1)

# %%
df7.head()
# Out:
#    product_id   color_id    size_id  stock  block_id  subfamily_id  price  \
# 0      151926  909958217   54666687     73      1969     335531561  25.95
# 1      151926  909958217  242364222    111      1969     335531561  25.95
# 2      151926  909958217  111455099     16      1969     335531561  25.95
# 3      151926  909958217   54666687     73      1969     335531561  25.95
# 4      151926  909958217   54666687     76      1969     335531561  25.95
#
#    date_number  min_position  mean_position  sales  weekday
# 0         71.0           5.0           13.5      0      1.0
# 1         72.0           5.0           13.5      0      2.0
# 2         72.0           5.0           13.5      0      2.0
# 3         72.0           5.0           13.5      0      2.0
# 4         77.0           5.0           13.5      0      0.0

# %% [markdown]
# # Models

# %%
X_train = df.drop("sales", axis=1).values
y_train = df["sales"].values

X_test = df7.drop("sales", axis=1).values
y_test = df7["sales"].values

# %% [markdown]
# # Best blocks

# %%
blocks = pd.DataFrame(df7["block_id"].unique())
blocks.rename({0:"block_id"}, axis=1, inplace = True)
blocks.sort_values(by = ["block_id"], inplace = True)
blocks.reset_index(drop=True, inplace=True)

# %%
blocks["number_products"] = blocks["block_id"].apply(lambda row: df7.loc[df7["block_id"] == row]["product_id"].value_counts().count())
blocks["sales"] = blocks["block_id"].apply(lambda row: df7.loc[df7["block_id"] == row]["sales"].sum())
blocks["stock"] = blocks["block_id"].apply(lambda row: df7.loc[df7["block_id"] == row]["stock"].sum())

# %%
blocks["values"] = blocks["sales"]

# %%
for e in blocks["block_id"]:
    value = 0
    g = df7.loc[df7["block_id"] == e]
    for x in range(g.shape[0]):
        value += g["price"].iloc[x] * g["sales"].iloc[x]
    blocks["values"].loc[blocks["block_id"] == e] = value
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
blocks["values"] = blocks["values"]/blocks["number_products"]

# %%
blocks.sort_values(by=["values"], ascending= False)
# Out:
#       block_id  number_products  sales  stock       values
# 373        404                1      0   5896  8389.500000
# 1338      1454                1      0   2996  5875.100000
# 1880      2037                2      0  38042  5255.250000
# 2273      2458                1      0   2689  4887.750000
# 1215      1322                1      0   3394  4819.500000
# 1016      1104                1      0  10499  4359.600000
# 1374      1491                1      0    232  4197.900000
# 2498      2704                1      0   1002  4172.000000
# 2133      2306                1      0  15544  3996.300000
# 1017      1105                4      0  13657  3554.950000
# 1857      2012                1      0    287  3498.250000
# 1384      1502                1      0    926  3496.500000
# 1710      1850                1      0   7770  3496.500000
# 1974      2139                1      0   1895  3451.350000
# 1828      1980                1      0   2379  3427.550000
# 14          15                1      0    295  3357.900000
# 1009      1097                3      0  33507  3314.383333
# 1873      2029                2      0   5652  3247.125000
# 1086      1178                1      0   1026  3231.550000
# 394        428                4      0  19142  3228.872500
# 2127      2300                4      0  13029  3034.962500
# 973       1058                2      0   9727  2936.500000
# 809        882                1      0   1144  2935.100000
# 2171      2346                2      0   1323  2867.900000
# 434        474                1      0   2843  2798.600000
# 201        215                1      0    483  2798.250000
# 350        380                4      0   8831  2772.350000
# 536        585                1      0    744  2741.550000
# 2447      2649                3      0  23189  2708.300000
# 1551      1679                4      0  32913  2697.187500
# ...        ...              ...    ...    ...          ...
# 53          55                1      0    541    90.650000
# 1898      2055                1      0   1078    90.650000
# 1220      1329                1      0   1224    90.650000
# 1014      1102                1      0    402    90.650000
# 1962      2125                1      0   1010    90.650000
# 1129      1226                1      0     46    90.650000
# 1824      1976                1      0     42    90.650000
# 2310      2496                1      0     12    83.400000
# 39          40                1      0    252    82.950000
# 429        468                1      0     10    82.950000
# 946       1029                1      0      2    77.700000
# 1664      1802                1      0     17    71.400000
# 343        373                1      0   1159    69.650000
# 2523      2732                1      0   2406    69.650000
# 2155      2329                1      0   1535    69.300000
# 2335      2524                1      0      1    59.700000
# 496        538                1      0      6    59.700000
# 2308      2494                1      0      1    59.700000
# 2404      2602                1      0   1147    55.650000
# 1839      1993                1      0    484    55.650000
# 2150      2323                1      0    974    55.650000
# 1634      1770                1      0     10    55.650000
# 275        298                1      0     21    55.300000
# 2074      2242                1      0     31    47.700000
# 1273      1387                1      0      2    47.400000
# 1181      1284                1      0   1011    41.650000
# 677        744                1      0    702    41.650000
# 1465      1587                1      0    138    35.700000
# 1369      1486                1      0    337    34.650000
# 1379      1497                1      0    347    34.650000
#
# [2564 rows x 5 columns]
